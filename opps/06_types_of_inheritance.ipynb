# %% [markdown]
# # Type of inheritance
# - simple
# -heirarichal
# -multiple
# -hybrid

# %% [markdown]
# # simple
# non private data members and methods

# %%
class Grandfather:
    def __init__(self,name,age):
        self.name=name
        self.age=age
    def show_details(self):
        return f"Name:{self.name},Age:{self.age}"
    def speak(self):
        return "Grandfather speaks wisely."

class Father(Grandfather):
    def __init__(self,name,age,occupation):
        super().__init__(name,age)
        self.occupation=occupation
    def show_occupation(self):
        return f"Occupation:{self.occupation}"
    def speak(self):
        return "Father speaks carefully"

# %%
father_obj=Father("john",50,"Engineer")
print(father_obj.show_details())
print(father_obj.show_occupation())
print(father_obj.speak())
# Out:
# Name:john,Age:50
# Occupation:Engineer
# Father speaks carefully

# %% [markdown]
# # Python Inheritance Types
#
# ## What is Inheritance?
#
# Inheritance is one of the four main principles of Object-Oriented Programming (OOP). It allows one class (called the **Child Class** or **Derived Class**) to inherit the properties and methods of another class (called the **Parent Class** or **Base Class**).
#
# ### Why Use Inheritance?
#
# - Reuse existing code.
# - Reduce code duplication.
# - Improve code organization.
# - Make programs easier to maintain.
# - Support method overriding and polymorphism.
#
# ### Syntax
#
# ```python
# class Parent:
#     pass
#
# class Child(Parent):
#     pass
# ```
#
# ---
#
# # Types of Inheritance in Python
#
# Python supports the following five types of inheritance:
#
# 1. Single Inheritance
# 2. Multiple Inheritance
# 3. Multilevel Inheritance
# 4. Hierarchical Inheritance
# 5. Hybrid Inheritance
#
# ---
#
# # 1. Single Inheritance
#
# ## Theory
#
# Single inheritance occurs when one child class inherits from one parent class.
#
# This is the simplest and most commonly used type of inheritance.
#
# ### Diagram
#
# ```
#
# Parent
# ↓
# Child
#
# ```
#
# ### Example
#
# ```python
# class Animal:
#     def sound(self):
#         print("Animal makes a sound")
#
# class Dog(Animal):
#     def bark(self):
#         print("Dog barks")
#
# dog = Dog()
#
# dog.sound()      # Inherited method
# dog.bark()       # Own method
# ```
#
# ### Output
#
# ```
# Animal makes a sound
# Dog barks
# ```
#
# ### Advantages
#
# - Simple and easy to understand.
# - Promotes code reuse.
# - Less memory usage compared to multiple inheritance.
#
# ---
#
# # 2. Multiple Inheritance
#
# ## Theory
#
# Multiple inheritance occurs when one child class inherits from more than one parent class.
#
# The child class can access methods and attributes from all parent classes.
#
# ### Diagram
#
# ```
#
# Parent1     Parent2
# \         /
# \       /
# Child
#
# ```
#
# ### Example
#
# ```python
# class Father:
#     def father_property(self):
#         print("Father's Property")
#
# class Mother:
#     def mother_property(self):
#         print("Mother's Property")
#
# class Child(Father, Mother):
#     def own_property(self):
#         print("Child's Property")
#
# child = Child()
#
# child.father_property()
# child.mother_property()
# child.own_property()
# ```
#
# ### Output
#
# ```
# Father's Property
# Mother's Property
# Child's Property
# ```
#
# ### Advantages
#
# - Can inherit features from multiple classes.
# - Improves code reusability.
#
# ### Disadvantage
#
# If two parent classes have methods with the same name, Python uses **Method Resolution Order (MRO)** to decide which method to execute.
#
# ---
#
# # 3. Multilevel Inheritance
#
# ## Theory
#
# Multilevel inheritance occurs when a class inherits from another child class.
#
# It forms a chain of inheritance.
#
# ### Diagram
#
# ```
#
# Grandparent
# ↓
# Parent
# ↓
# Child
#
# ```
#
# ### Example
#
# ```python
# class Grandfather:
#     def house(self):
#         print("Grandfather owns a house")
#
# class Father(Grandfather):
#     def car(self):
#         print("Father owns a car")
#
# class Son(Father):
#     def bike(self):
#         print("Son owns a bike")
#
# son = Son()
#
# son.house()
# son.car()
# son.bike()
# ```
#
# ### Output
#
# ```
# Grandfather owns a house
# Father owns a car
# Son owns a bike
# ```
#
# ### Advantages
#
# - Allows inheritance across multiple levels.
# - Easy to extend functionality step by step.
#
# ---
#
# # 4. Hierarchical Inheritance
#
# ## Theory
#
# Hierarchical inheritance occurs when multiple child classes inherit from the same parent class.
#
# Each child gets access to the parent's methods independently.
#
# ### Diagram
#
# ```
#
# Parent
# /   \
# /     \
# Child1 Child2
#
# ```
#
# ### Example
#
# ```python
# class Animal:
#     def eat(self):
#         print("Animal is eating")
#
# class Dog(Animal):
#     def bark(self):
#         print("Dog barks")
#
# class Cat(Animal):
#     def meow(self):
#         print("Cat meows")
#
# dog = Dog()
# cat = Cat()
#
# dog.eat()
# dog.bark()
#
# cat.eat()
# cat.meow()
# ```
#
# ### Output
#
# ```
# Animal is eating
# Dog barks
# Animal is eating
# Cat meows
# ```
#
# ### Advantages
#
# - Multiple classes can reuse the same parent class.
# - Reduces duplicate code.
#
# ---
#
# # 5. Hybrid Inheritance
#
# ## Theory
#
# Hybrid inheritance is a combination of two or more inheritance types.
#
# Python supports hybrid inheritance because it supports multiple inheritance.
#
# ### Diagram
#
# ```
#
# Grandparent
# |
# Parent
# /     \
# Child1 Child2
# \     /
# FinalChild
#
# ```
#
# ### Example
#
# ```python
# class A:
#     def method_a(self):
#         print("Method A")
#
# class B(A):
#     def method_b(self):
#         print("Method B")
#
# class C(A):
#     def method_c(self):
#         print("Method C")
#
# class D(B, C):
#     def method_d(self):
#         print("Method D")
#
# obj = D()
#
# obj.method_a()
# obj.method_b()
# obj.method_c()
# obj.method_d()
# ```
#
# ### Output
#
# ```
# Method A
# Method B
# Method C
# Method D
# ```
#
# ### Advantages
#
# - Combines the benefits of multiple inheritance structures.
# - Suitable for large applications.
#
# ### Disadvantage
#
# - Can become complex.
# - Requires understanding of Method Resolution Order (MRO).
#
# ---
#
# # Summary Table
#
# | Inheritance Type | Parent Classes | Child Classes | Example |
# |------------------|---------------|--------------|---------|
# | Single | 1 | 1 | Animal → Dog |
# | Multiple | 2 or more | 1 | Father + Mother → Child |
# | Multilevel | Chain | Chain | Grandfather → Father → Son |
# | Hierarchical | 1 | Multiple | Animal → Dog, Cat |
# | Hybrid | Combination | Combination | A → B, C → D |
#
# ---
#
# # Key Points to Remember
#
# - Inheritance allows one class to reuse another class's code.
# - Parent class is also called **Base Class** or **Superclass**.
# - Child class is also called **Derived Class** or **Subclass**.
# - `super()` is used to access parent class methods and constructors.
# - Python supports all five types of inheritance.
# - Multiple and Hybrid inheritance use **Method Resolution Order (MRO)** to determine which method is executed first.
#
# ---
#
# # Real-Life Examples
#
# | Inheritance Type | Real-Life Example |
# |------------------|-------------------|
# | Single | Vehicle → Car |
# | Multiple | Person inherits traits from Father and Mother |
# | Multilevel | Grandfather → Father → Son |
# | Hierarchical | Teacher → MathTeacher, ScienceTeacher |
# | Hybrid | Company Employee System with multiple roles |
#
# ---
#
# # Conclusion
#
# Inheritance is one of the most powerful features of Object-Oriented Programming. It enables code reuse, better organization, and easier maintenance. Understanding all five types of inheritance is essential before learning **Method Overriding**, **Polymorphism**, and **MRO (Method Resolution Order)**.
