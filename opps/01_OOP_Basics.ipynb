# %% [markdown]
# # Object-Oriented Programming (OOP) Basics in Python

# %% [markdown]
# ## 🎯 Objective
#
# In this notebook, you'll learn the fundamentals of Object-Oriented Programming (OOP) in Python, including classes, objects, attributes, methods, constructors, and different types of variables.

# %% [markdown]
# ## 📚 Topics Covered
#
# - What is OOP?
# - Why use OOP?
# - Class
# - Object
# - Attributes
# - Methods
# - Constructor (__init__)
# - Instance Variables
# - Class Variables
# - Creating Multiple Objects

# %% [markdown]
# ## 1. What is OOP?
#
# Object-Oriented Programming (OOP) is a programming paradigm that organizes code into objects. Each object contains data (attributes) and functions (methods).
#
# It helps make code reusable, modular, and easier to maintain.

# %%
# sellers
seller1name ="a"
seller1adderess="abc"
seller1money=123

# %%
seller2name ="b"
seller2adderess="def"
seller2money=1766
seller3name ="d"
seller3adderess="vbvc"
seller3money=333

# %%
sellerName=["A","B","D"]

# %%
sellerName[2]
# Out:
# 'D'

# %% [markdown]
# ### 1.produral/functional opproach is not a lot helpful for real world use cases

# %% [markdown]
# it is always helpul if we could create a blueprint of what we want and the create multiple copies via it

# %% [markdown]
# # so opps help us in doing below things .
# 1.define our own datatypes
# 2.generality to specificity
# opps is thus a programming paradigm which help us to write letter code.

# %% [markdown]
# ## 2. Why OOP?
#
# ✔ Code Reusability
#
# ✔ Better Organization
#
# ✔ Easy Maintenance
#
# ✔ Scalability
#
# ✔ Real-world Modeling

# %% [raw]
# # 1.class
# # 2.object
# # 3.encapsulation
# # 4.inheritence
# # 5.polymorphism
# # 6.abstraction

# %% [markdown]
# # class

# %% [markdown]
#  1.blueprint
#
#  2.self defined datatype
#
#  all datatypes are built in class

# %%
a=5
print(type(a))
# Out:
# <class 'int'>

# %%
b=5.5
print(type(b))
# Out:
# <class 'float'>

# %% [markdown]
# ### in class we need to define
#  1.data/attributes/property
#
#  for instance :- in car color , brand,name,topspeed
#
#  2.behaviour/method
#
#  for instance :- in car accelerate(),brake(),start()

# %%
l1=[1,2,3]

# %%
l1.append(4)

# %%
c=4+5j

# %%
c.real
# Out:
# 4.0

# %%
c.imag
# Out:
# 5.0

# %% [markdown]
# # creating our own class

# %%
class Car:
    pass

# %%
Car
# Out:
# __main__.Car

# %%
int
# Out:
# int

# %% [markdown]
# # object

# %% [markdown]
#  an object is an instance of our class
#
#  "everything in python is an object"

# %%
c1=3+6j
c2=4+5j

# %%
print(type(c1))
# Out:
# <class 'complex'>

# %%
class Car:
    pass

# %%
swift=Car()

# %%
print(type(swift))
# Out:
# <class '__main__.Car'>

# %%
l1=[]
t3=()

# %%
#python gives us 'object literal' for built in types
